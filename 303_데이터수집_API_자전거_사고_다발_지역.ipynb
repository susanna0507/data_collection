# %% [markdown]
# <a href="https://colab.research.google.com/github/susanna0507/data_collection/blob/master/303_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A7%91_API_%EC%9E%90%EC%A0%84%EA%B1%B0_%EC%82%AC%EA%B3%A0_%EB%8B%A4%EB%B0%9C_%EC%A7%80%EC%97%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 공공데이터 포털
# - https://www.data.go.kr/index.do
# - https://www.data.go.kr/data/15056681/openapi.do
# - 도로교통공단_자전거사고다발지역정보서비스

# %% [markdown]
# #### 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/ai_chat_python'
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/ai_chat_python

# %%
import requests

# %%
url = 'http://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle'
key = '###'
url += '?ServiceKey='+ key +'&searchYearCd=2021&siDo=11&guGun=110&type=json&numOfRows=10&pageNo=1'  # &type=json& 추가함

response = requests.get(url)
print(response)        # <Response [200]>
# print(response.text)

print(dir(response))
print(type(response))   # requests.models.Response
print(response.json)    # Response.json of <Response [200]>
# Out:
# <Response [200]>
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# <class 'requests.models.Response'>
# <bound method Response.json of <Response [200]>>

# %%
print(response.text)
# Out:
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6806238,"afos_id":"2022083","bjd_cd":"1111010700","spot_cd":"11110001","sido_sgg_nm":"서울특별시 종로구1","spot_nm":"서울특별시 종로구 적선동(적선현대빌딩 부근)","occrrnc_cnt":5,"caslt_cnt":5,"dth_dnv_cnt":0,"se_dnv_cnt":1,"sl_dnv_cnt":2,"wnd_dnv_cnt":2,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[126.97466371,37.57536392],[126.97462919,37.57508612],[126.97452695,37.574819],[126.97436092,37.57457282],[126.97413749,37.57435704],[126.97386523,37.57417996],[126.97355462,37.57404837],[126.97321758,37.57396734],[126.97286708,37.57393998],[126.97251657,37.57396734],[126.97217954,37.57404837],[126.97186892,37.57417996],[126.97159667,37.57435704],[126.97137323,37.57457282],[126.97120721,37.574819],[126.97110497,37.57508612],[126.97107045,37.57536392],[126.97110497,37.57564171],[126.97120721,37.57590883],[126.97137323,37.576155],[126.97159667,37.57637077],[126.97186892,37.57654786],[126.97217954,37.57667944],[126.97251657,37.57676047],[126.97286708,37.57678783],[126.97321758,37.57676047],[126.97355462,37.57667944],[126.97386523,37.57654786],[126.97413749,37.57637077],[126.97436092,37.576155],[126.97452695,37.57590883],[126.97462919,37.57564171],[126.97466371,37.57536392]]]}","lo_crd":"126.972867077854","la_crd":"37.575363915713"},{"afos_fid":6806239,"afos_id":"2022083","bjd_cd":"1111015700","spot_cd":"11110002","sido_sgg_nm":"서울특별시 종로구2","spot_nm":"서울특별시 종로구 인의동(종로4가사거리 부근)","occrrnc_cnt":4,"caslt_cnt":4,"dth_dnv_cnt":0,"se_dnv_cnt":1,"sl_dnv_cnt":0,"wnd_dnv_cnt":3,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[126.99939223,37.57083711],[126.99935771,37.5705593],[126.99925547,37.57029217],[126.99908945,37.57004597],[126.99886601,37.56983018],[126.99859376,37.56965308],[126.99828314,37.56952149],[126.99794611,37.56944045],[126.9975956,37.56941309],[126.9972451,37.56944045],[126.99690806,37.56952149],[126.99659745,37.56965308],[126.99632519,37.56983018],[126.99610176,37.57004597],[126.99593573,37.57029217],[126.99583349,37.5705593],[126.99579897,37.57083711],[126.99583349,37.57111492],[126.99593573,37.57138206],[126.99610176,37.57162825],[126.99632519,37.57184403],[126.99659745,37.57202112],[126.99690806,37.57215271],[126.9972451,37.57223375],[126.9975956,37.57226111],[126.99794611,37.57223375],[126.99828314,37.57215271],[126.99859376,37.57202112],[126.99886601,37.57184403],[126.99908945,37.57162825],[126.99925547,37.57138206],[126.99935771,37.57111492],[126.99939223,37.57083711]]]}","lo_crd":"126.997595602156","la_crd":"37.570837112544"},{"afos_fid":6805883,"afos_id":"2022083","bjd_cd":"1111012300","spot_cd":"11110003","sido_sgg_nm":"서울특별시 종로구3","spot_nm":"서울특별시 종로구 서린동(종로구청입구교차로 부근)","occrrnc_cnt":4,"caslt_cnt":4,"dth_dnv_cnt":0,"se_dnv_cnt":0,"sl_dnv_cnt":4,"wnd_dnv_cnt":0,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[126.98089454,37.56987425],[126.98086002,37.56959644],[126.98075778,37.5693293],[126.98059176,37.5690831],[126.98036832,37.56886731],[126.98009607,37.56869021],[126.97978545,37.56855861],[126.97944842,37.56847758],[126.97909791,37.56845021],[126.97874741,37.56847758],[126.97841037,37.56855861],[126.97809976,37.56869021],[126.9778275,37.56886731],[126.97760407,37.5690831],[126.97743804,37.5693293],[126.9773358,37.56959644],[126.97730128,37.56987425],[126.9773358,37.57015207],[126.97743804,37.5704192],[126.97760407,37.5706654],[126.9778275,37.57088119],[126.97809976,37.57105828],[126.97841037,37.57118987],[126.97874741,37.57127091],[126.97909791,37.57129827],[126.97944842,37.57127091],[126.97978545,37.57118987],[126.98009607,37.57105828],[126.98036832,37.57088119],[126.98059176,37.5706654],[126.98075778,37.5704192],[126.98086002,37.57015207],[126.98089454,37.56987425]]]}","lo_crd":"126.979097913739","la_crd":"37.569874254294"}]},"totalCount":3,"numOfRows":3,"pageNo":1}

# %%
url = 'http://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle'
key = '###'

queryParams = {'serviceKey': key,
              'searchYearCd': 2017,
              'siDo' : 11,
              'guGun' : 200,
              'type': 'json',
              'numOfRows':10,
              'pageNo':1
              }

response = requests.get(url, queryParams)
print(response)        # <Response [200]>
# print(response.text)

print(dir(response))
print(type(response))   # requests.models.Response
print(response.json)    # Response.json of <Response [200]>
print(response.text)
# Out:
# <Response [200]>
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# <class 'requests.models.Response'>
# <bound method Response.json of <Response [200]>>
# {"resultCode":"00","resultMsg":"NORMAL_CODE","items":{"item":[{"afos_fid":6411124,"afos_id":"2018032","bjd_cd":"1120010500","spot_cd":"11200001","sido_sgg_nm":"서울특별시 성동구1","spot_nm":"서울특별시 성동구 마장동(고산자교 부근)","occrrnc_cnt":7,"caslt_cnt":7,"dth_dnv_cnt":1,"se_dnv_cnt":1,"sl_dnv_cnt":4,"wnd_dnv_cnt":1,"geom_json":"{\"type\":\"Polygon\",\"coordinates\":[[[127
096291,37.54882038],[127.06112893,37.54906665],[127.06135237,37.5492825],[127.06162462,37.54945965],[127.06193524,37.54959128],[127.06227227,37.54967233],[127.06262278,37.5496997],[127.06297328,37.54967233],[127.06331032,37.54959128],[127.06362093,37.54945965],[127.06389319,37.5492825],[127.06411662,37.54906665],[127.06428265,37.54882038],[127.06438489,37.54855317],[127.06441941,37.54827528]]]}","lo_crd":"127.062622777920","la_crd":"37.548275275385"},{"afos_fid":6411129,"afos_id":"2018032","bjd_cd":"1120010100","spot_cd":"11200004","sido_sgg_nm":"서울특별시 성동구4","spot_nm":"서울특별시 성동구 상왕십리동(황학교 부근)","occrrnc_cnt":4,"caslt_cnt":4,"dth_dnv_cnt":0,"se_dnv_cnt":2,"sl_dnv_cnt":2 ...

# %%
print(type(response.json())) #dict
response.json()
# Out:
# {'resultCode': '00',
#  'resultMsg': 'NORMAL_CODE',
#  'items': {'item': [{'afos_fid': 6411124,
#     'afos_id': '2018032',
#     'bjd_cd': '1120010500',
#     'spot_cd': '11200001',
#     'sido_sgg_nm': '서울특별시 성동구1',
#     'spot_nm': '서울특별시 성동구 마장동(고산자교 부근)',
#     'occrrnc_cnt': 7,
#     'caslt_cnt': 7,
#     'dth_dnv_cnt': 1,
#     'se_dnv_cnt': 1,
#     'sl_dnv_cnt': 4,
#     'wnd_dnv_cnt': 1,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.03956189,37.57225254],[127.03952737,37.57197473],[127.03942513,37.5717076],[127.03925911,37.57146141],[127.03903567,37.57124562],[127.03876342,37.57106853],[127.0384528,37.57093694],[127.03811577,37.5708559],[127.03776526,37.57082854],[127.03741476,37.5708559],[127.03707772,37.57093694],[127.03676711,37.57106853],[127.03649485,37.57124562],[127.03627142,37.57146141],[127.03610539,37.5717076],[127.03600316,37.57197473],[127.03596863,37.57225254],[127.03600316,37.57253034],[127.03610539,37.57279747],[127.03627142,37.57304366],[127.03649485,37.57325944],[127.03676711,37.57343653],[127.03707772,37.57356811],[127.03741476,37.57364915],[127.03776526,37.57367651],[127.03811577,37.57364915],[127.0384528,37.57356811],[127.03876342,37.57343653],[127.03903567,37.57325944],[127.03925911,37.57304366],[127.03942513,37.57279747],[127.03952737,37.57253034],[127.03956189,37.57225254]]]}',
#     'lo_crd': '127.037765263857',
#     'la_crd': '37.572252537526'},
#    {'afos_fid': 6411126,
#     'afos_id': '2018032',
#     'bjd_cd': '1120011400',
#     'spot_cd': '11200002',
#     'sido_sgg_nm': '서울특별시 성동구2',
#     'spot_nm': '서울특별시 성동구 성수동1가(대림공인중개사사무소 부근)',
#     'occrrnc_cnt': 5,
#     'caslt_cnt': 5,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 1,
#     'sl_dnv_cnt': 3,
#     'wnd_dnv_cnt': 1,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127
#     'lo_crd': '127.023532710068',
#     'la_crd': '37.571737017350'},
#    {'afos_fid': 6411445,
#     'afos_id': '2018032',
#     'bjd_cd': '1120010200',
#     'spot_cd': '11200005',
#     'sido_sgg_nm': '서울특별시 성동구5',
#     'spot_nm': '서울특별시 성동구 하왕십리동(무학교 부근)',
#     'occrrnc_cnt': 4,
#     'caslt_cnt': 4,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 1,
#     'sl_dnv_cnt': 2,
#     'wnd_dnv_cnt': 1,
#     'geom_json': '{"type":"Polygon","coordinates":[[[127.03181904,37.56939483],[127.03178452,37.56911702],[127.03168228,37.56884988],[127.03151626,37.56860368],[127.03129282,37.56838788],[127.03102057,37.56821078],[127.03070995,37.56807918],[127.03037292,37.56799815],[127.03002241,37.56797078],[127.02967191,37.56799815],[127.02933487,37.56807918],[127.02902426,37.56821078],[127.028752,37.56838788],[127.02852857,37.56860368],[127.02836254,37.56884988],[127.0282603,37.56911702],[127.02822578,37.56939483],[127.0282603,37.56967265],[127.02836254,37.56993979],[127.02852857,37.57018598],[127.028752,37.57040177],[127.02902426,37.57057887],[127.02933487,37.57071046],[127.02967191,37.5707915],[127.03002241,37.57081886],[127.03037292,37.5707915],[127.03070995,37.57071046],[127.03102057,37.57057887],[127.03129282,37.57040177],[127.03151626,37.57018598],[127.03168228,37.56993979],[127.03178452,37.56967265],[127.03181904,37.56939483]]]}',
#     'lo_crd': '127.030022411306',
#     'la_crd': '37.569394833806'}]},
#  'totalCount': 5,
#  'numOfRows': 5,
#  'pageNo': 1}

# %%
# item 접근
w_data = response.json()['items']['item']
print(type(w_data))  #list
print((len(w_data)))  #l갯수

for row in range(len(w_data)):
  print('spot_nm', w_data[row]['spot_nm'])
  print('경도:', w_data[row]['lo_crd'])
  print('위도:', w_data[row]['la_crd'])
# Out:
# <class 'list'>
# 5
# spot_nm 서울특별시 성동구 마장동(고산자교 부근)
# 경도: 127.037765263857
# 위도: 37.572252537526
# spot_nm 서울특별시 성동구 성수동1가(대림공인중개사사무소 부근)
# 경도: 127.046242912881
# 위도: 37.541250431663
# spot_nm 서울특별시 성동구 송정동(성동세무서 부근)
# 경도: 127.062622777920
# 위도: 37.548275275385
# spot_nm 서울특별시 성동구 상왕십리동(황학교 부근)
# 경도: 127.023532710068
# 위도: 37.571737017350
# spot_nm 서울특별시 성동구 하왕십리동(무학교 부근)
# 경도: 127.030022411306
# 위도: 37.569394833806

# %%
result = []
data = response.json()
w_data = data['items']['item']
for row in range(len(w_data)):
  line = {}
  line ['spot_nm'] = w_data[row]['spot_nm']
  line ['lo_crd'] = w_data[row]['lo_crd']
  line ['la_crd'] = w_data[row]['la_crd']
  result.append(line)

# %%
result
# Out:
# [{'spot_nm': '서울특별시 성동구 마장동(고산자교 부근)',
#   'lo_crd': '127.037765263857',
#   'la_crd': '37.572252537526'},
#  {'spot_nm': '서울특별시 성동구 성수동1가(대림공인중개사사무소 부근)',
#   'lo_crd': '127.046242912881',
#   'la_crd': '37.541250431663'},
#  {'spot_nm': '서울특별시 성동구 송정동(성동세무서 부근)',
#   'lo_crd': '127.062622777920',
#   'la_crd': '37.548275275385'},
#  {'spot_nm': '서울특별시 성동구 상왕십리동(황학교 부근)',
#   'lo_crd': '127.023532710068',
#   'la_crd': '37.571737017350'},
#  {'spot_nm': '서울특별시 성동구 하왕십리동(무학교 부근)',
#   'lo_crd': '127.030022411306',
#   'la_crd': '37.569394833806'}]

# %%
import json

print(dir(json))
# Out:
# ['JSONDecodeError', 'JSONDecoder', 'JSONEncoder', '__all__', '__author__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_default_decoder', '_default_encoder', 'codecs', 'decoder', 'detect_encoding', 'dump', 'dumps', 'encoder', 'load', 'loads', 'scanner']

# %%
#, ensure_ascii=False : 유니코드로 변환되는 작업 방지
# indent = "\t" : 들여쓰기를 탭으로 설정
with open('./source/cycle.json', 'w' ,encoding='utf-8') as f:
  json.dump(result,f, indent = '\t', ensure_ascii=False) # dump(obj, fp)

# %%
with open('./source/cycle.json', 'r', encoding='utf-8') as f:
  data = json.load(f)
  print(data)
# Out:
# [{'spot_nm': '서울특별시 성동구 마장동(고산자교 부근)', 'lo_crd': '127.037765263857', 'la_crd': '37.572252537526'}, {'spot_nm': '서울특별시 성동구 성수동1가(대림공인중개사사무소 부근)', 'lo_crd': '127.046242912881', 'la_crd': '37.541250431663'}, {'spot_nm': '서울특별시 성동구 송정동(성동세무서 부근)', 'lo_crd': '127.062622777920', 'la_crd': '37.548275275385'}, {'spot_nm': '서울특별시 성동구 상왕십리동(황학교 부근)', 'lo_crd': '127.023532710068', 'la_crd': '37.571737017350'}, {'spot_nm': '서울특별시 성동구 하왕십리동(무학교 부근)', 'lo_crd': '127.030022411306', 'la_crd': '37.569394833806'}]

# %% [markdown]
# dump - 파일로 저장
# dumps - 데이터로 저장
# load - 파일에 내용 읽어올 때
# loads - 변수에 있는 내용을 읽어올 때

# %%
json_str = '[1,2,3,4]'
print(type(json_str))
data = json.loads(json_str)
print(type(data))
# Out:
# <class 'str'>
# <class 'list'>

# %%
json.dumps(data)
# Out:
# '[1, 2, 3, 4]'

# %%
json_str = '{"a":1,"b":2,"c":3}'
print(type(json_str))

data = json.loads(json_str)
print(type(data))
# Out:
# <class 'str'>
# <class 'dict'>

# %%
json.dumps(data)
# Out:
# '{"a": 1, "b": 2, "c": 3}'

# %%
json_str ='''
  {
    "name" : "홍길동",
    "age" : 30
  }
'''

print(type(json_str))

data = json.loads(json_str)
print(type(data))
print(data)
# Out:
# <class 'str'>
# <class 'dict'>
# {'name': '홍길동', 'age': 30}

# %%
json.dumps(data)
# Out:
# '{"name": "\\ud64d\\uae38\\ub3d9", "age": 30}'
